# %% [markdown]
# # 7. Expanding
#
# ## 1. 定制客户邮件

# %%
# 我们可以在推理那章学习到如何对一个评论判断其情感倾向
sentiment = "消极的"

# 一个产品的评价
review = f"""
他们在11月份的季节性销售期间以约49美元的价格出售17件套装，折扣约为一半。\
但由于某些原因（可能是价格欺诈），到了12月第二周，同样的套装价格全都涨到了70美元到89美元不等。\
11件套装的价格也上涨了大约10美元左右。\
虽然外观看起来还可以，但基座上锁定刀片的部分看起来不如几年前的早期版本那么好。\
不过我打算非常温柔地使用它，例如，\
我会先在搅拌机中将像豆子、冰、米饭等硬物研磨，然后再制成所需的份量，\
切换到打蛋器制作更细的面粉，或者在制作冰沙时先使用交叉切割刀片，然后使用平面刀片制作更细/不粘的效果。\
制作冰沙时，特别提示：\
将水果和蔬菜切碎并冷冻（如果使用菠菜，则轻轻煮软菠菜，然后冷冻直到使用；\
如果制作果酱，则使用小到中号的食品处理器），这样可以避免在制作冰沙时添加太多冰块。\
大约一年后，电机发出奇怪的噪音，我打电话给客服，但保修已经过期了，所以我不得不再买一个。\
总的来说，这些产品的总体质量已经下降，因此它们依靠品牌认可和消费者忠诚度来维持销售。\
货物在两天内到达。
"""

# %%
from tool import get_completion

prompt = f"""
你是一位客户服务的AI助手。
你的任务是给一位重要客户发送邮件回复。
根据客户通过“```”分隔的评价，生成回复以感谢客户的评价。提醒模型使用评价中的具体细节
用简明而专业的语气写信。
作为“AI客户代理”签署电子邮件。
客户评论：
```{review}```
评论情感：{sentiment}
"""

response = get_completion(prompt)
print(response)
# Out:
# **主题：感谢您的反馈**
#
# 尊敬的客户，
#
# 感谢您抽出时间分享关于我们产品的详细使用体验。我们非常重视您的意见，并已认真记录了您提到的价格波动、产品设计变化以及电机问题。
#
# 对于您在11月和12月遇到的价格差异，我们深感抱歉。我们的定价策略旨在为客户提供有竞争力的优惠，但我们会进一步审查这一情况以确保透明度。同时，您提到的刀片底座和电机耐用性问题对我们改进产品至关重要，我们会将您的反馈转达给产品团队进行进一步评估。
#
# 我们非常欣赏您分享的使用技巧，例如预处理食材和分步骤使用不同刀片，这些细节对其他用户也非常有帮助。遗憾的是，您的保修问题未能得到及时解决，我们理解这给您带来了不便。
#
# 您的反馈对我们持续提升产品质量和服务至关重要。如果您未来有任何疑问或需要进一步协助，请随时联系我们。
#
# 再次感谢您的支持与信任。
#
# 此致，
# 敬礼
#
# **AI客户代理**
# [您的公司名称]
# [联系方式]

# %% [markdown]
# ## 2. 引入温度系数

# %%
# 第一运行

prompt = f"""
你是一位客户服务的AI助手。
你的任务是给一位重要客户发送邮件回复。
根据客户通过“```”分隔的客户电子邮件生成回复，以感谢客户的评价。
如果情感是积极的或中性的，感谢他们的评价。
如果情感是消极的，道歉并建议他们联系客户服务。
请确保使用评论中的具体细节。
以简明和专业的语气写信。
以“AI客户代理”的名义签署电子邮件。
客户评价：```{review}```
评论情感：{sentiment}
"""

response = get_completion(prompt, temperature=0.7)
print(response)
# Out:
# **主题：感谢您的反馈**
#
# 尊敬的客户，
#
# 感谢您分享关于我们产品的详细使用体验。我们非常重视您的意见，并感谢您花时间提供如此具体的反馈。
#
# 对于您提到的价格波动、产品质量以及电机问题，我们深感抱歉。您的体验未能达到预期，我们对此表示诚挚的歉意。我们始终致力于为客户提供高质量的产品和服务，但很显然，我们在某些方面未能做到这一点。
#
# 为了更好地解决您的问题，我们建议您联系我们的客户服务团队。他们将能够为您提供更具体的帮助，并进一步处理您遇到的问题。您可以通过[客户服务联系方式]与我们取得联系。
#
# 再次感谢您的反馈，这对我们改进产品和服务至关重要。如果您有任何其他问题或需要进一步的帮助，请随时与我们联系。
#
# 此致，
# 敬礼
#
# **AI客户代理**
# [公司名称] 客户服务团队

# %%
# 第二运行

prompt = f"""
你是一位客户服务的AI助手。
你的任务是给一位重要客户发送邮件回复。
根据客户通过“```”分隔的客户电子邮件生成回复，以感谢客户的评价。
如果情感是积极的或中性的，感谢他们的评价。
如果情感是消极的，道歉并建议他们联系客户服务。
请确保使用评论中的具体细节。
以简明和专业的语气写信。
以“AI客户代理”的名义签署电子邮件。
客户评价：```{review}```
评论情感：{sentiment}
"""

response = get_completion(prompt, temperature=0.7)
print(response)
# Out:
# **主题：感谢您的反馈**
#
# 尊敬的客户，
#
# 感谢您分享关于我们产品的详细使用体验。我们非常重视您的反馈，并对您在购买和使用过程中遇到的不便深感抱歉。
#
# 我们理解您对价格波动以及产品耐用性的担忧，并对此表示诚挚的歉意。您的观察对我们改进产品和服务非常重要。关于您提到的电机问题以及保修期的限制，我们深感遗憾。为了更好地协助您解决具体问题，我们建议您直接联系我们的客户服务团队，他们将竭诚为您提供进一步的帮助。
#
# 同时，我们非常感谢您分享的使用技巧，例如在制作冰沙时预处理食材的方法，这些细节对其他用户也非常有价值。
#
# 如果您愿意，我们的客户服务团队可以为您提供更具体的支持。您可以通过[客户服务邮箱]或[电话号码]与他们取得联系。
#
# 再次感谢您花时间提供反馈，并给予我们改进的机会。
#
# 此致，
# 敬礼
#
# **AI客户代理**
# [公司名称]客户服务团队
