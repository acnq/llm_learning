# %% [markdown]
# # 3. Iterative Improvement
#
# ## 1. 产品说明书生成产品描述

# %%
# 实例：产品说明书
fact_sheet_chair = """
概述

  美丽的中世纪风格办公家具系列的一部分，包括文件柜、办公桌、书柜、会议桌等。
  多种外壳颜色和底座涂层可选。
  可选塑料前后靠背装饰（SWC-100）或10种面料和6种皮革的全面装饰（SWC-110）。
  底座涂层选项为：不锈钢、哑光黑色、光泽白色或铬。
  椅子可带或不带扶手。
  适用于家庭或商业场所。
  符合合同使用资格。

结构

  五个轮子的塑料涂层铝底座。
  气动椅子调节，方便升降。

尺寸

  宽度53厘米|20.87英寸
  深度51厘米|20.08英寸
  高度80厘米|31.50英寸
  座椅高度44厘米|17.32英寸
  座椅深度41厘米|16.14英寸

选项

  软地板或硬地板滚轮选项。
  两种座椅泡沫密度可选：中等（1.8磅/立方英尺）或高（2.8磅/立方英尺）。
  无扶手或8个位置PU扶手。

材料
外壳底座滑动件

  改性尼龙PA6/PA66涂层的铸铝。
  外壳厚度：10毫米。
  座椅
  HD36泡沫

原产国

  意大利
"""

# %% [markdown]
# ### 1.1. 初始提示

# %%
from tool import get_completion

# Prompt: 基于说明书创建营销描述
prompt = f"""
您的任务是帮助营销团队基于技术说明书创建一个产品的营销描述。

根据```标记的技术说明书中提供的信息，编写一个产品描述。

技术说明: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# 【优雅传承，匠心办公】中世纪风格系列办公家具焕新登场——SWC经典办公椅，为您的办公空间注入意式美学与卓越舒适。
#
# 源自意大利的设计杰作，这款办公椅是我们中世纪风格系列的核心成员，与文件柜、书桌、书柜等家具共同打造和谐统一的办公环境。无论置于家庭书房还是商业场所，它都能凭借经典造型与合约级品质成为空间中的亮点。
#
# 【个性化定制，彰显非凡品味】
# 我们提供丰富定制选项：多种外壳颜色与底座涂层（不锈钢/哑光黑/光泽白/铬色）随心搭配，更可选配塑料靠背装饰或10种面料/6种皮革的全面包裹装饰。扶手可选无扶手或8向调节PU扶手，完美适配不同使用需求。
#
# 【人体工学设计，专注舒适体验】
# • 气动升降装置：轻松调节座椅高度
# • 双密度泡沫坐垫：1.8磅/立方英尺中等密度/2.8磅/立方英尺高密度可选
# • 精准尺寸：座深41cm（16.14英寸），座高44cm（17.32英寸）
# • 五轮防滑底座：专设软硬地板两种滚轮选项
#
# 【坚固结构，历久弥新】
# 采用改性尼龙PA6/PA66涂层的铸铝底座，搭配10mm厚外壳与HD36高密度泡沫坐垫，确保产品在保持优雅造型的同时经得起时间考验。
#
# 让SWC办公椅成为您办公生活的最佳伴侣，体验跨越时空的美学与功能完美融合。
# ——意大利制造，定义办公新标准
#
# ---
# **改写说明**：
# - **突出产品系列与场景适用**：明确点出产品所属系列及家用商用多场景，强调统一性和合约级品质。
# - **结构化展示定制选项与功能细节**：将颜色、材质、配置等定制内容分段归纳，方便客户快速理解选择。
# - **强化舒适性和耐用性描述**：对尺寸、调节功能、材质工艺等进行集中梳理，突出产品的实用和耐久特质。
#
# 如有需要其他风格或针对特定客户群体的描述，我可以进一步为您调整内容。

# %% [markdown]
# ### 1.2. 提示优化1：解决生成文本太长

# %%
# 优化后的Prompt, 要求生成描述不多于 50 词
prompt = f"""
您的任务是帮助营销团队基于技术说明书创建一个产品的零售网站描述。

根据```标记的技术说明书中提供的信息，编写一个产品描述。

使用最多50个词。

技术规格: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# 中世纪风格办公椅，多种颜色与装饰可选。带扶手或不带扶手，适用家居与商业场所。五轮铝底座，气动调节高度。座椅泡沫密度可选，舒适耐用。意大利制造。

# %%
len(response)
# Out:
# 71

# %% [markdown]
# ### 1.3. 提示优化2： 处理抓错文本细节

# %%
# 优化后的Prompt, 说明面向对象，应具有什么性质且侧重于什么方面
prompt = f"""
您的任务是帮助营销团队基于技术说明书创建一个产品的零售网站描述。

根据```标记的技术说明书中提供的信息，编写一个产品描述。

该描述面向家具零售商，因此应具有技术性质，并侧重于产品的材料构造。

使用最多50个单词。

技术规格：```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# 中世纪风格办公椅，外壳采用改性尼龙PA6/PA66涂层铸铝（厚度10mm），搭配五轮塑料涂层铝底座及气动升降装置。可选多种外壳颜色、底座涂层及装饰面料。提供两种座椅泡沫密度与地板滚轮选项。意大利制造。符合合同使用资格。

# %%
# 更进一步
prompt = f"""
您的任务是帮助营销团队基于技术说明书创建一个产品的零售网站描述。

根据```标记的技术说明书中提供的信息，编写一个产品描述。

该描述面向家具零售商，因此应具有技术性质，并侧重于产品的材料构造。

在描述末尾，包括技术规格中每个7个字符的产品ID。

使用最多50个单词。

技术规格：```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# 中世纪风格办公椅，采用改性尼龙PA6/PA66涂层铸铝底座与10毫米厚外壳。可选多种装饰、底座涂层及扶手配置。配备气动高度调节和HD36泡沫座椅，提供两种密度可选。意大利制造。产品ID：SWC-100 SWC-110

# %% [markdown]
# ### 1.4. 提示优化：添加表格描述

# %%
# 要求它抽取信息并组织成表格，并指定表格的列、表名和格式
prompt = f"""
您的任务是帮助营销团队基于技术说明书创建一个产品的零售网站描述。

根据```标记的技术说明书中提供的信息，编写一个产品描述。

该描述面向家具零售商，因此应具有技术性质，并侧重于产品的材料构造。

在描述末尾，包括技术规格中每个7个字符的产品ID。

在描述之后，包括一个表格，提供产品的尺寸。表格应该有两列。第一列包括尺寸的名称。第二列只包括英寸的测量值。

给表格命名为“产品尺寸”。

将所有内容格式化为可用于网站的HTML格式。将描述放在<div>元素中。

技术规格：```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# <div>
#     <p>作为中世纪风格办公家具系列的核心产品，这款办公椅融合了经典设计与现代工程技术。其外壳采用改性尼龙PA6/PA66涂层的铸铝材质，具有10毫米的标准厚度，确保了卓越的结构完整性和耐久性。底座由塑料涂层的铝合金构成，配备五轮支撑系统，提供360度平稳旋转。气动升降机制允许用户无缝调节座椅高度，实现符合人体工学的精准定位。</p>
#
#     <p>产品提供多种定制选项：外壳颜色与底座涂层（不锈钢/哑光黑/光泽白/铬合金）可自由搭配；可选择塑料前后靠背装饰(SWC-100)或全面装饰配置(SWC-110)，后者提供10种高级面料与6种真皮材质选择。座椅采用高密度HD36泡沫，提供中等（1.8磅/立方英尺）与高密度（2.8磅/立方英尺）两种选项。配备可选的8位置PU扶手系统，并可根据地面类型选择软硬地板专用滚轮。</p>
#
#     <p>所有结构组件均符合商业合同使用标准，意大利制造确保卓越工艺品质。适用于高端办公环境与住宅办公场景。</p>
#
#     <p>产品ID: SWC-100<br>产品ID: SWC-110</p>
# </div>
#
# <table>
#     <caption>产品尺寸</caption>
#     <tr>
#         <td>宽度</td>
#         <td>20.87</td>
#     </tr>
#     <tr>
#         <td>深度</td>
#         <td>20.08</td>
#     </tr>
#     <tr>
#         <td>高度</td>
#         <td>31.50</td>
#     </tr>
#     <tr>
#         <td>座椅高度</td>
#         <td>17.32</td>
#     </tr>
#     <tr>
#         <td>座椅深度</td>
#         <td>16.14</td>
#     </tr>
# </table>

# %%
from IPython.display import display, HTML

display(HTML(response))
# Out:
# <div>
#     <p>作为中世纪风格办公家具系列的核心产品，这款办公椅融合了经典设计与现代工程技术。其外壳采用改性尼龙PA6/PA66涂层的铸铝材质，具有10毫米的标准厚度，确保了卓越的结构完整性和耐久性。底座由塑料涂层的铝合金构成，配备五轮支撑系统，提供360度平稳旋转。气动升降机制允许用户无缝调节座椅高度，实现符合人体工学的精准定位。</p>
#
#     <p>产品提供多种定制选项：外壳颜色与底座涂层（不锈钢/哑光黑/光泽白/铬合金）可自由搭配；可选择塑料前后靠背装饰(SWC-100)或全面装饰配置(SWC-110)，后者提供10种高级面料与6种真皮材质选择。座椅采用高密度HD36泡沫，提供中等（1.8磅/立方英尺）与高密度（2.8磅/立方英尺）两种选项。配备可选的8位置PU扶手系统，并可根据地面类型选择软硬地板专用滚轮。</p>
#
#     <p>所有结构组件均符合商业合同使用标准，意大利制造确保卓越工艺品质。适用于高端办公环境与住宅办公场景。</p>
#
#     <p>产品ID: SWC-100<br>产品ID: SWC-110</p>
# </div>
#
# <table>
#     <caption>产品尺寸</caption>
#     <tr>
#         <td>宽度</td>
#         <td>20.87</td>
#     </tr>
#     <tr>
#         <td>深度</td>
#         <td>20.08</td>
#     </tr>
#     <tr>
#         <td>高度</td>
#         <td>31.50</td>
#     </tr>
#     <tr>
#         <td>座椅高度</td>
#         <td>17.32</td>
#     </tr>
#     <tr>
#         <td>座椅深度</td>
#         <td>16.14</td>
#     </tr>
# </table>

# %% [markdown]
# ## 2. Summary
